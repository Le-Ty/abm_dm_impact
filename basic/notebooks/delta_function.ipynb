# %% [markdown]
# # Delta Function

# %% [markdown]
# This notebook presents an agent-based model that simulates the propagation of a disease through a network.
# It demonstrates how to use the [agentpy](https://agentpy.readthedocs.io) package to create and visualize networks, use the interactive module, and perform different types of sensitivity analysis.

# %%
# Model design
import agentpy as ap
import networkx as nx 
import random 
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt 
import seaborn as sns
import IPython

np.random.seed(42)

# %%
import os

if os.path.isdir("../notebooks"):
    os.chdir("..")

from utils import viz, delta_function

from agent import Person

from model import VirusModel, VirusModel_baseline

# %% [markdown]
# ## About the model
#
# The agents of this model are people, which can be in one of the following three conditions: susceptible to the disease (S), infected (I), or recovered (R). The agents are connected to each other through a small-world network of peers. At every time-step, infected agents can infect their peers or recover from the disease based on random chance.

# %% [markdown]
# ## Defining the model

# %% [markdown]
# We define a new agent type :class:`Person` by creating a subclass of :class:`Agent`.
# This agent has two methods: :func:`setup` will be called automatically at the agent's creation,
# and :func:`being_sick` will be called by the :func:`Model.step` function.
# Three tools are used within this class:
#
# - :attr:`Agent.p` returns the parameters of the model
# - :func:`Agent.neighbors` returns a list of the agents' peers in the network
# - :func:`random.random` returns a uniform random draw between 0 and 1
#
# wealth by race https://www.federalreserve.gov/econres/notes/feds-notes/disparities-in-wealth-by-race-and-ethnicity-in-the-2019-survey-of-consumer-finances-20200928.html
#
# rank for the US:
# https://www.federalreserve.gov/econres/notes/feds-notes/wealth-inequality-and-the-racial-wealth-gap-accessible-20211022.htm#fig3

# %%
values = plt.hist(np.random.beta(1.5, 5, 10000),

                  bins=200, density=True)

plt.show()

# %%
import matplotlib.pyplot as plt

values = plt.hist(np.random.beta(5, 3, 10000),

                  bins=200, density=True)

plt.show()

# %% [markdown]
# Next, we define our model :class:`VirusModel` by creating a subclass of :class:`Model`.
# The four methods of this class will be called automatically at different steps of the simulation,
# as described in :ref:`overview_simulation`.

# %% [markdown]
# ## Running a simulation

# %% [markdown]
# To run our model, we define a dictionary with our parameters.
# We then create a new instance of our model, passing the parameters as an argument,
# and use the method :func:`Model.run` to perform the simulation and return it's output.

# %%
parameters = {
    'my_parameter':42,
    'agents':10,
    'steps':100,
    'wealth_appeal_corr': 0, # >0 more wealth higher appeal chance
    'acc': 0.8, # accuracy of fraud prdediction
    'appeal_wealth': 0.2 # minimal wealth needed for appeal (could also become a param for distr. eventually)
    #'wealth_impact'
    
}

model_baseline = VirusModel_baseline(parameters)
results_baseline = model_baseline.run() 

df_baseline = results_baseline['variables']['Person']

viz(df_baseline, df_baseline.index.get_level_values('t'), df_baseline['wealth'].astype(float), df_baseline['race'])
# Out:
# 0.3333333333333333
# 0.6666666666666666
# Completed: 1 steps0.6666666666666666
# Completed: 2 steps0.6666666666666666
# Completed: 3 steps0.6666666666666666
# Completed: 4 steps0.6666666666666666
# Completed: 5 steps0.6666666666666666
# Completed: 6 steps0.6666666666666666
# Completed: 7 steps0.6666666666666666
# Completed: 8 steps0.6666666666666666
# Completed: 9 steps0.6666666666666666
# Completed: 10 steps0.6666666666666666
# Completed: 11 steps0.6666666666666666
# Completed: 12 steps0.6666666666666666
# Completed: 13 steps0.6666666666666666
# Completed: 14 steps0.6666666666666666
# Completed: 15 steps0.6666666666666666
# Completed: 16 steps0.6666666666666666
# Completed: 17 steps0.6666666666666666
# Completed: 18 steps0.6666666666666666
# Completed: 19 steps0.6666666666666666
# Completed: 20 steps0.6666666666666666
# Completed: 21 steps0.6666666666666666
# Completed: 22 steps0.6666666666666666
# Completed: 23 steps0.6666666666666666
# Completed: 24 steps0.6666666666666666
# Completed: 25 steps0.6666666666666666
# Completed: 26 steps0.6666666666666666
# Completed: 27 steps0.6666666666666666
# Completed: 28 steps0.6666666666666666
# Completed: 29 steps0.6666666666666666
# Completed: 30 steps0.6666666666666666
# Completed: 31 steps0.6666666666666666
# Completed: 32 steps
# /Users/uni/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/uni/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# 0.6666666666666666
# Completed: 33 steps0.6666666666666666
# Completed: 34 steps0.6666666666666666
# Completed: 35 steps0.6666666666666666
# Completed: 36 steps0.6666666666666666
# Completed: 37 steps0.6666666666666666
# Completed: 38 steps0.6666666666666666
# Completed: 39 steps0.6666666666666666
# Completed: 40 steps0.6666666666666666
# Completed: 41 steps0.6666666666666666
# Completed: 42 steps0.6666666666666666
# Completed: 43 steps0.6666666666666666
# Completed: 44 steps0.6666666666666666
# Completed: 45 steps0.6666666666666666
# Completed: 46 steps0.6666666666666666
# Completed: 47 steps0.6666666666666666
# Completed: 48 steps0.6666666666666666
# Completed: 49 steps0.6666666666666666
# Completed: 50 steps0.6666666666666666
# Completed: 51 steps0.6666666666666666
# Completed: 52 steps0.6666666666666666
# Completed: 53 steps0.6666666666666666
# Completed: 54 steps0.6666666666666666
# Completed: 55 steps0.6666666666666666
# Completed: 56 steps0.6666666666666666
# Completed: 57 steps0.6666666666666666
# Completed: 58 steps0.6666666666666666
# Completed: 59 steps0.6666666666666666
# Completed: 60 steps0.6666666666666666
# Completed: 61 steps0.6666666666666666
# Completed: 62 steps0.6666666666666666
# Completed: 63 steps0.6666666666666666
# Completed: 64 steps0.6666666666666666
# Completed: 65 steps0.6666666666666666
# Completed: 66 steps0.6666666666666666
# Completed: 67 steps0.6666666666666666
# Completed: 68 steps0.6666666666666666
# Completed: 69 steps0.6666666666666666
# Completed: 70 steps0.6666666666666666
# Completed: 71 steps0.6666666666666666
# Completed: 72 steps0.6666666666666666
# Completed: 73 steps0.6666666666666666
# Completed: 74 steps0.6666666666666666
# Completed: 75 steps0.6666666666666666
# Completed: 76 steps0.6666666666666666
# Completed: 77 steps0.6666666666666666
# Completed: 78 steps0.6666666666666666
# Completed: 79 steps0.6666666666666666
# Completed: 80 steps0.6666666666666666
# Completed: 81 steps0.6666666666666666
# Completed: 82 steps0.6666666666666666
# Completed: 83 steps0.6666666666666666
# Completed: 84 steps0.6666666666666666
# Completed: 85 steps0.6666666666666666
# Completed: 86 steps0.6666666666666666
# Completed: 87 steps0.6666666666666666
# Completed: 88 steps0.6666666666666666
# Completed: 89 steps0.6666666666666666
# Completed: 90 steps0.6666666666666666
# Completed: 91 steps0.3333333333333333
# Completed: 92 steps0.3333333333333333
# Completed: 93 steps0.3333333333333333
# Completed: 94 steps0.3333333333333333
# Completed: 95 steps0.3333333333333333
# Completed: 96 steps0.3333333333333333
# Completed: 97 steps0.6666666666666666
# Completed: 98 steps0.6666666666666666
# Completed: 99 steps0.6666666666666666
# Completed: 100 steps
# Run time: 0:00:00.583357
# Simulation finished
# /Users/uni/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /Users/uni/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
parameters = {
    'my_parameter':42,
    'agents':1000,
    'steps':100,
    'wealth_appeal_corr': 0, # >0 more wealth higher appeal chance
    'acc': 0.8, # accuracy of fraud prdediction
    'appeal_wealth': 0.2 # minimal wealth needed for appeal (could also become a param for distr. eventually)
    # 'my_parameter':42, # influence of resources on 
    #'wealth_impact'
    
}

model = VirusModel(parameters)
results = model.run() 

df = results['variables']['Person']

viz(df, df.index.get_level_values('t'), df['wealth'].astype(float), df['race'])
# Out:
# Completed: 100 steps
# Run time: 0:00:17.139450
# Simulation finished

# %%
# create baseline value
df_b1 = df_baseline.iloc[(df_baseline['race'] == 1).values] 
baseline1 = df_b1.groupby(level='t').mean()
# df_b
df_b0 = df_baseline.iloc[(df_baseline['race'] == 0).values] 
baseline0 = df_b0.groupby(level='t').mean()

# %%
df_x1 = df.iloc[(df['race'] == 1).values] 
df_wb1 = df_x1['wealth'] - baseline1['wealth']
df_x1['wealth'] = df_wb1




df_x0 = df.iloc[(df['race'] == 0).values] 
df_wb0 = df_x0['wealth'] - baseline0['wealth']
df_x0['wealth'] = df_wb0

df_xb = pd.concat([df_x0, df_x1])
# Out:
# /var/folders/_3/m4zxq5yx589d0965c6l5j1q80000gp/T/ipykernel_35794/2096043862.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1['wealth'] = df_wb1
# /var/folders/_3/m4zxq5yx589d0965c6l5j1q80000gp/T/ipykernel_35794/2096043862.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x0['wealth'] = df_wb0

# %%
viz(df_xb, df_xb.index.get_level_values('t'), df_xb['wealth'].astype(float), df_xb['race'])

# %% [markdown]
# ## Delta Function

# %%
# run baseline and normal model and save results
model_baseline = VirusModel_baseline(parameters)
results_baseline = model_baseline.run() 

df_baseline = results_baseline['variables']['Person']

model = VirusModel(parameters)
results = model.run() 

df = results['variables']['Person']
# Out:
# 0.6666666666666666
# 0.532
# Completed: 1 steps0.532
# Completed: 2 steps0.532
# Completed: 3 steps0.532
# Completed: 4 steps0.532
# Completed: 5 steps0.532
# Completed: 6 steps0.532
# Completed: 7 steps0.532
# Completed: 8 steps0.532
# Completed: 9 steps0.532
# Completed: 10 steps0.532
# Completed: 11 steps0.532
# Completed: 12 steps0.532
# Completed: 13 steps0.532
# Completed: 14 steps0.532
# Completed: 15 steps0.532
# Completed: 16 steps0.532
# Completed: 17 steps0.532
# Completed: 18 steps0.532
# Completed: 19 steps0.528
# Completed: 20 steps0.528
# Completed: 21 steps0.532
# Completed: 22 steps0.532
# Completed: 23 steps0.536
# Completed: 24 steps0.54
# Completed: 25 steps0.54
# Completed: 26 steps0.54
# Completed: 27 steps0.54
# Completed: 28 steps0.54
# Completed: 29 steps0.54
# Completed: 30 steps0.544
# Completed: 31 steps0.548
# Completed: 32 steps0.556
# Completed: 33 steps0.552
# Completed: 34 steps0.552
# Completed: 35 steps0.556
# Completed: 36 steps0.556
# Completed: 37 steps0.556
# Completed: 38 steps0.556
# Completed: 39 steps0.556
# Completed: 40 steps0.556
# Completed: 41 steps0.556
# Completed: 42 steps0.556
# Completed: 43 steps0.556
# Completed: 44 steps0.556
# Completed: 45 steps0.556
# Completed: 46 steps0.556
# Completed: 47 steps0.556
# Completed: 48 steps0.556
# Completed: 49 steps0.556
# Completed: 50 steps0.556
# Completed: 51 steps0.556
# Completed: 52 steps0.556
# Completed: 53 steps0.556
# Completed: 54 steps0.56
# Completed: 55 steps0.56
# Completed: 56 steps0.56
# Completed: 57 steps0.56
# Completed: 58 steps0.56
# Completed: 59 steps0.56
# Completed: 60 steps0.556
# Completed: 61 steps0.556
# Completed: 62 steps0.556
# Completed: 63 steps0.556
# Completed: 64 steps0.556
# Completed: 65 steps0.556
# Completed: 66 steps0.556
# Completed: 67 steps0.56
# Completed: 68 steps0.564
# Completed: 69 steps0.564
# Completed: 70 steps0.564
# Completed: 71 steps0.56
# Completed: 72 steps0.564
# Completed: 73 steps0.564
# Completed: 74 steps0.564
# Completed: 75 steps0.564
# Completed: 76 steps0.56
# Completed: 77 steps0.564
# Completed: 78 steps0.568
# Completed: 79 steps0.568
# Completed: 80 steps0.568
# Completed: 81 steps0.568
# Completed: 82 steps0.568
# Completed: 83 steps0.568
# Completed: 84 steps0.568
# Completed: 85 steps0.564
# Completed: 86 steps0.568
# Completed: 87 steps0.568
# Completed: 88 steps0.568
# Completed: 89 steps0.564
# Completed: 90 steps0.568
# Completed: 91 steps0.568
# Completed: 92 steps0.564
# Completed: 93 steps0.568
# Completed: 94 steps0.564
# Completed: 95 steps0.568
# Completed: 96 steps0.568
# Completed: 97 steps0.568
# Completed: 98 steps0.564
# Completed: 99 steps0.564
# Completed: 100 steps
# Run time: 0:00:17.142263
# Simulation finished
# Completed: 100 steps
# Run time: 0:00:17.452959
# Simulation finished

# %%
# def delta_function(disc_axis, y_axis, df, df_baseline):
#     """ Delta function visualizes absolute difference between baseline scenario and more complex scenario """

#     df_b1 = df_baseline.iloc[(df_baseline[disc_axis] == 1).values] 
#     df_wb1 = df.iloc[(df[disc_axis] == 1).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
#     df_x1 = df.iloc[(df[disc_axis] == 1).values]
#     df_x1[y_axis] = df_wb1
    
#     df_b0 = df_baseline.iloc[(df_baseline[disc_axis] == 0).values] 
#     df_wb0 = df.iloc[(df[disc_axis] == 0).values] [y_axis] - df_b0.groupby(level='t').mean()[y_axis]
#     df_x0 = df.iloc[(df[disc_axis] == 0).values]
#     df_x0[y_axis] = df_wb0
    
#     return pd.concat([df_x0, df_x1])

# %%
df_xb = delta_function('race', 'wealth', df, df_baseline)
viz(df_xb, df_xb.index.get_level_values('t'), df_xb['wealth'].astype(float), df_xb['race'])
# Out:
# /Users/uni/Documents/Git/abm/basic/utils.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1[y_axis] = df_wb1
# /Users/uni/Documents/Git/abm/basic/utils.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x0[y_axis] = df_wb0

# %% [markdown]
# Do I want this or do I want just one line that indicates if r0 or r1 profits more? This
