# %% [markdown]
# # Delta Function Appeal

# %% [markdown]
# This notebook presents an agent-based model that simulates the propagation of a disease through a network.
# It demonstrates how to use the [agentpy](https://agentpy.readthedocs.io) package to create and visualize networks, use the interactive module, and perform different types of sensitivity analysis.

# %%
# Model design
import agentpy as ap
import networkx as nx 
import random 
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt 
import seaborn as sns
import IPython
import pickle
np.random.seed(42)

# %%
import os

if os.path.isdir("../notebooks"):
    os.chdir("..")

from utils import viz, delta_function, transform_pd

from agent import Person

from model import VirusModel, VirusModel_baseline

# %% [markdown]
# ## About the model
#
# The agents of this model are people, which can be in one of the following three conditions: susceptible to the disease (S), infected (I), or recovered (R). The agents are connected to each other through a small-world network of peers. At every time-step, infected agents can infect their peers or recover from the disease based on random chance.

# %% [markdown]
# ## Running a simulation

# %% [markdown]
# To run our model, we define a dictionary with our parameters.
# We then create a new instance of our model, passing the parameters as an argument,
# and use the method :func:`Model.run` to perform the simulation and return it's output.

# %%
parameters = {
    'my_parameter':42,
    'agents':200,
    'steps':100,
    'wealth_appeal_corr': 0, # >0 more wealth higher appeal chance
    'acc': 0.8, # accuracy of fraud prdediction
    'appeal_wealth': 0.3, # minimal wealth needed for appeal (could also become a param for distr. eventually)
    #'wealth_impact'
    'clf': 'pretrained', # None, 'hist'
    'expi': None,
    'fraud_det': 0,
    'fairness_metrics' : False
    
}

sample = ap.Sample(parameters, n=1)
# model_baseline = VirusModel_baseline(parameters)
exp = ap.Experiment(VirusModel_baseline, sample, iterations =1, record = True)
results_baseline = exp.run()
# Out:
# Scheduled runs: 1
# using predtrined clf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 19
#      17 # model_baseline = VirusModel_baseline(parameters)
#      18 exp = ap.Experiment(VirusModel_baseline, sample, iterations =1, record = True)
# ---> 19 results_baseline = exp.run()
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/experiment.py:247, in Experiment.run(self, n_jobs, pool, display, **kwargs)
#     244 i = -1
#     245 for run_id in self.run_ids:
#     246     self._add_single_output_to_combined(
# --> 247         self._single_sim(run_id), combined_output)
#     248     if display:
#     249         i += 1
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/experiment.py:183, in Experiment._single_sim(self, run_id)
#     181     results = model.run(display=False, seed=self._random[run_id])
#     182 else:
# --> 183     results = model.run(display=False)
#     184 if 'variables' in results and self.record is False:
#     185     del results['variables']  # Remove dynamic variables from record
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/model.py:378, in Model.run(self, steps, seed, display)
#     376 self.sim_setup(steps, seed)
#     377 while self.running:
# --> 378     self.sim_step()
#     379     if display:
#     380         print(f"\rCompleted: {self.t} steps", end='')
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/model.py:327, in Model.sim_step(self)
#     324 """ Proceeds the simulation by one step, incrementing `Model.t` by 1
#     325 and then calling :func:`Model.step` and :func:`Model.update`."""
#     326 self.t += 1
# --> 327 self.step()
#     328 self.update()
#     329 if self.t >= self._steps:
#
# File ~/Documents/Git/abm/basic/model.py:56, in VirusModel_baseline.step(self, clf, expi)
#      50 #EXECUTING FUNCTIONS
#      51
#      52
#      53 #ACCESS & TREATMENT
#      54 self.agents.fraud_algo(self.p.clf)
# ---> 56 self.agents.fairness_metrics(self.agents)
#      59 self.agents.appeal()
#      62 #BUREAUCRATICS
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/sequences.py:102, in AttrIter.__call__(self, *args, **kwargs)
#     101 def __call__(self, *args, **kwargs):
# --> 102     return AttrIter([func_obj(*args, **kwargs) for func_obj in self])
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/sequences.py:102, in <listcomp>(.0)
#     101 def __call__(self, *args, **kwargs):
# --> 102     return AttrIter([func_obj(*args, **kwargs) for func_obj in self])
#
# File ~/Documents/Git/abm/basic/agent.py:145, in Person.fairness_metrics(self, data, print)
#     143 temp_dpd = demographic_parity_ratio( y_true=y_true, y_pred=y_pred, sensitive_features=i)
#     144 dpd.append(temp_dpd)
# --> 145 temp_eod = equalized_odds_ratio( y_true=y_true, y_pred=y_pred, sensitive_features=i)
#     146 if print:
#     147     print('dpd',temp_dpd)
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_fairness_metrics.py:183, in equalized_odds_ratio(y_true, y_pred, sensitive_features, method, sample_weight)
#     145 def equalized_odds_ratio(
#     146     y_true, y_pred, *, sensitive_features, method="between_groups", sample_weight=None
#     147 ) -> float:
#     148     """Calculate the equalized odds ratio.
#     149
#     150     The smaller of two metrics: `true_positive_rate_ratio` and
#    (...)
#     181         The equalized odds ratio
#     182     """
# --> 183     eo = _get_eo_frame(y_true, y_pred, sensitive_features, sample_weight)
#     185     return min(eo.ratio(method=method))
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_fairness_metrics.py:192, in _get_eo_frame(y_true, y_pred, sensitive_features, sample_weight)
#     190 sw_dict = {"sample_weight": sample_weight}
#     191 sp = {"tpr": sw_dict, "fpr": sw_dict}
# --> 192 eo = MetricFrame(
#     193     metrics=fns,
#     194     y_true=y_true,
#     195     y_pred=y_pred,
#     196     sensitive_features=sensitive_features,
#     197     sample_params=sp,
#     198 )
#     199 return eo
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_metric_frame.py:103, in _deprecate_metric_frame_init.<locals>.compatible_metric_frame_init(self, metric, *args, **kwargs)
#      91     warnings.warn(
#      92         (
#      93             "The positional argument 'metric' has been replaced "
#    (...)
#      98         FutureWarning,
#      99     )
#     101 # Call the new constructor with positional arguments passed as keyword arguments
#     102 # and with the `metric` keyword argument renamed to `metrics`.
# --> 103 new_metric_frame_init(self, **metric_arg_dict, **positional_dict, **kwargs)
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_metric_frame.py:338, in MetricFrame.__init__(self, metrics, y_true, y_pred, sensitive_features, control_features, sample_params)
#     335     nameset.add(name)
#     337 # Create the basic results
# --> 338 result = DisaggregatedResult.create(
#     339     data=all_data,
#     340     annotated_functions=annotated_funcs,
#     341     sensitive_feature_names=self._sf_names,
#     342     control_feature_names=self._cf_names,
#     343 )
#     345 # Build into cache
#     346 self._result_cache = dict()
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_disaggregated_result.py:361, in DisaggregatedResult.create(data, annotated_functions, sensitive_feature_names, control_feature_names)
#     359 # Calculate the 'overall' values
#     360 if control_feature_names is None:
# --> 361     overall = apply_to_dataframe(data, metric_functions=annotated_functions)
#     362 else:
#     363     temp = data.groupby(by=control_feature_names).apply(
#     364         apply_to_dataframe, metric_functions=annotated_functions
#     365     )
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_disaggregated_result.py:52, in apply_to_dataframe(data, metric_functions)
#      50 values = dict()
#      51 for function_name, metric_function in metric_functions.items():
# ---> 52     values[function_name] = metric_function(data)
#      53 # correctly handle zero provided metrics
#      54 if len(values) == 0:
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_annotated_metric_function.py:106, in AnnotatedMetricFunction.__call__(self, df)
#     102 for func_arg_name, data_arg_name in self.kw_argument_mapping.items():
#     103     # Need to convert to list first in case we have 2D arrays
#     104     kwargs[func_arg_name] = np.asarray(list(df[data_arg_name]))
# --> 106 result = self.func(*args, **kwargs)
#     108 return result
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_base_metrics.py:113, in true_positive_rate(y_true, y_pred, sample_weight, pos_label)
#      85 r"""Calculate the true positive rate (also called sensitivity, recall, or hit rate).
#      86
#      87 Read more in the :ref:`User Guide <custom_fairness_metrics>`.
#    (...)
#     108     The true positive rate for the data
#     109 """
#     110 unique_labels = _get_labels_for_confusion_matrix(
#     111     np.vstack((y_true, y_pred)), pos_label
#     112 )
# --> 113 tnr, fpr, fnr, tpr = skm.confusion_matrix(
#     114     y_true,
#     115     y_pred,
#     116     sample_weight=sample_weight,
#     117     labels=unique_labels,
#     118     normalize="true",
#     119 ).ravel()
#     120 return tpr
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/metrics/_classification.py:317, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     232 def confusion_matrix(
#     233     y_true, y_pred, *, labels=None, sample_weight=None, normalize=None
#     234 ):
#     235     """Compute confusion matrix to evaluate the accuracy of a classification.
#     236
#     237     By definition a confusion matrix :math:`C` is such that :math:`C_{i, j}`
#    (...)
#     315     (0, 2, 1, 1)
#     316     """
# --> 317     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     318     if y_type not in ("binary", "multiclass"):
#     319         raise ValueError("%s is not supported" % y_type)
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/metrics/_classification.py:113, in _check_targets(y_true, y_pred)
#     111 if y_type == "binary":
#     112     try:
# --> 113         unique_values = np.union1d(y_true, y_pred)
#     114     except TypeError as e:
#     115         # We expect y_true and y_pred to be of the same data type.
#     116         # If `y_true` was provided to the classifier as strings,
#     117         # `y_pred` given by the classifier will also be encoded with
#     118         # strings. So we raise a meaningful error
#     119         raise TypeError(
#     120             "Labels in y_true and y_pred should be of the same type. "
#     121             f"Got y_true={np.unique(y_true)} and "
#    (...)
#     124             "the true labels."
#     125         ) from e
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/numpy/lib/arraysetops.py:932, in union1d(ar1, ar2)
#     898 @array_function_dispatch(_union1d_dispatcher)
#     899 def union1d(ar1, ar2):
#     900     """
#     901     Find the union of two arrays.
#     902
#    (...)
#     930     array([1, 2, 3, 4, 6])
#     931     """
# --> 932     return unique(np.concatenate((ar1, ar2), axis=None))
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/numpy/lib/arraysetops.py:332, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     328 ar = np.asanyarray(ar).flatten()
#     330 optional_indices = return_index or return_inverse
# --> 332 if optional_indices:
#     333     perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     334     aux = ar[perm]
#
# KeyboardInterrupt:

# %%
    
df_baseline = results_baseline['variables']['Person']

viz(df_baseline, df_baseline.index.get_level_values('t'), df_baseline['wealth'].astype(float), df_baseline['race'])

# %%
# # plot wealth against fraud and fraud prediction
# df_baseline['fraud_pred']
# df_baseline.index.get_level_values('t')
# a = df_baseline.loc[:,['wealth','fraud_pred']]
# # sns.violinplot(a, x = 'wealth', y = 'fraud_pred')
# df_baseline.columns = df_baseline.columns.map(''.join)
# print(df_baseline.index.names)
# df_baseline.xs('t', level=0, axis=0, drop_level=True)
# # viz(df_baseline, df_baseline.index.get_level_values('t'), df_baseline['wealth'].astype(float), df_baseline['fraud_pred'])

# %%
parameters_b = {
    'my_parameter':42,
    'agents':200,
    'steps':100,
    'wealth_appeal_corr': 0, # >0 more wealth higher appeal chance
    'acc': 0.8, # accuracy of fraud prdediction
    'appeal_wealth': 0.3, # minimal wealth needed for appeal (could also become a param for distr. eventually)
    #'wealth_impact'
    'clf': 'pretrained', # None, 'hist'
    'expi': None,
    'fraud_det': 0,
    'fairness_metrics' : False
    
    
}


sample_b = ap.Sample(parameters_b, n=1)
model_b = VirusModel(parameters_b)
exp = ap.Experiment(VirusModel, sample, iterations =1, record = True)
results_baseline = exp.run()
# Out:
# Scheduled runs: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      19 model_b = VirusModel(parameters_b)
#      20 exp = ap.Experiment(VirusModel, sample, iterations =1, record = True)
# ---> 21 results_baseline = exp.run()
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/experiment.py:247, in Experiment.run(self, n_jobs, pool, display, **kwargs)
#     244 i = -1
#     245 for run_id in self.run_ids:
#     246     self._add_single_output_to_combined(
# --> 247         self._single_sim(run_id), combined_output)
#     248     if display:
#     249         i += 1
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/experiment.py:183, in Experiment._single_sim(self, run_id)
#     181     results = model.run(display=False, seed=self._random[run_id])
#     182 else:
# --> 183     results = model.run(display=False)
#     184 if 'variables' in results and self.record is False:
#     185     del results['variables']  # Remove dynamic variables from record
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/model.py:378, in Model.run(self, steps, seed, display)
#     376 self.sim_setup(steps, seed)
#     377 while self.running:
# --> 378     self.sim_step()
#     379     if display:
#     380         print(f"\rCompleted: {self.t} steps", end='')
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/model.py:327, in Model.sim_step(self)
#     324 """ Proceeds the simulation by one step, incrementing `Model.t` by 1
#     325 and then calling :func:`Model.step` and :func:`Model.update`."""
#     326 self.t += 1
# --> 327 self.step()
#     328 self.update()
#     329 if self.t >= self._steps:
#
# File ~/Documents/Git/abm/basic/model.py:167, in VirusModel.step(self, clf, expi)
#     161 #EXECUTING FUNCTIONS
#     162
#     163
#     164 #ACCESS & TREATMENT
#     165 self.agents.fraud_algo(self.p.clf)
# --> 167 self.agents.fairness_metrics(self.agents)
#     170 # self.agents.appeal()
#     171
#     172
#     173 #BUREAUCRATICS
#     174 self.agents.convict()
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/sequences.py:102, in AttrIter.__call__(self, *args, **kwargs)
#     101 def __call__(self, *args, **kwargs):
# --> 102     return AttrIter([func_obj(*args, **kwargs) for func_obj in self])
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/agentpy/sequences.py:102, in <listcomp>(.0)
#     101 def __call__(self, *args, **kwargs):
# --> 102     return AttrIter([func_obj(*args, **kwargs) for func_obj in self])
#
# File ~/Documents/Git/abm/basic/agent.py:145, in Person.fairness_metrics(self, data, print)
#     143 temp_dpd = demographic_parity_ratio( y_true=y_true, y_pred=y_pred, sensitive_features=i)
#     144 dpd.append(temp_dpd)
# --> 145 temp_eod = equalized_odds_ratio( y_true=y_true, y_pred=y_pred, sensitive_features=i)
#     146 if print:
#     147     print('dpd',temp_dpd)
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_fairness_metrics.py:183, in equalized_odds_ratio(y_true, y_pred, sensitive_features, method, sample_weight)
#     145 def equalized_odds_ratio(
#     146     y_true, y_pred, *, sensitive_features, method="between_groups", sample_weight=None
#     147 ) -> float:
#     148     """Calculate the equalized odds ratio.
#     149
#     150     The smaller of two metrics: `true_positive_rate_ratio` and
#    (...)
#     181         The equalized odds ratio
#     182     """
# --> 183     eo = _get_eo_frame(y_true, y_pred, sensitive_features, sample_weight)
#     185     return min(eo.ratio(method=method))
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_fairness_metrics.py:192, in _get_eo_frame(y_true, y_pred, sensitive_features, sample_weight)
#     190 sw_dict = {"sample_weight": sample_weight}
#     191 sp = {"tpr": sw_dict, "fpr": sw_dict}
# --> 192 eo = MetricFrame(
#     193     metrics=fns,
#     194     y_true=y_true,
#     195     y_pred=y_pred,
#     196     sensitive_features=sensitive_features,
#     197     sample_params=sp,
#     198 )
#     199 return eo
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_metric_frame.py:103, in _deprecate_metric_frame_init.<locals>.compatible_metric_frame_init(self, metric, *args, **kwargs)
#      91     warnings.warn(
#      92         (
#      93             "The positional argument 'metric' has been replaced "
#    (...)
#      98         FutureWarning,
#      99     )
#     101 # Call the new constructor with positional arguments passed as keyword arguments
#     102 # and with the `metric` keyword argument renamed to `metrics`.
# --> 103 new_metric_frame_init(self, **metric_arg_dict, **positional_dict, **kwargs)
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_metric_frame.py:338, in MetricFrame.__init__(self, metrics, y_true, y_pred, sensitive_features, control_features, sample_params)
#     335     nameset.add(name)
#     337 # Create the basic results
# --> 338 result = DisaggregatedResult.create(
#     339     data=all_data,
#     340     annotated_functions=annotated_funcs,
#     341     sensitive_feature_names=self._sf_names,
#     342     control_feature_names=self._cf_names,
#     343 )
#     345 # Build into cache
#     346 self._result_cache = dict()
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_disaggregated_result.py:361, in DisaggregatedResult.create(data, annotated_functions, sensitive_feature_names, control_feature_names)
#     359 # Calculate the 'overall' values
#     360 if control_feature_names is None:
# --> 361     overall = apply_to_dataframe(data, metric_functions=annotated_functions)
#     362 else:
#     363     temp = data.groupby(by=control_feature_names).apply(
#     364         apply_to_dataframe, metric_functions=annotated_functions
#     365     )
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_disaggregated_result.py:52, in apply_to_dataframe(data, metric_functions)
#      50 values = dict()
#      51 for function_name, metric_function in metric_functions.items():
# ---> 52     values[function_name] = metric_function(data)
#      53 # correctly handle zero provided metrics
#      54 if len(values) == 0:
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_annotated_metric_function.py:106, in AnnotatedMetricFunction.__call__(self, df)
#     102 for func_arg_name, data_arg_name in self.kw_argument_mapping.items():
#     103     # Need to convert to list first in case we have 2D arrays
#     104     kwargs[func_arg_name] = np.asarray(list(df[data_arg_name]))
# --> 106 result = self.func(*args, **kwargs)
#     108 return result
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/fairlearn/metrics/_base_metrics.py:191, in false_positive_rate(y_true, y_pred, sample_weight, pos_label)
#     163 r"""Calculate the false positive rate (also called fall-out).
#     164
#     165 Read more in the :ref:`User Guide <custom_fairness_metrics>`.
#    (...)
#     186     The false positive rate for the data
#     187 """
#     188 unique_labels = _get_labels_for_confusion_matrix(
#     189     np.vstack((y_true, y_pred)), pos_label
#     190 )
# --> 191 tnr, fpr, fnr, tpr = skm.confusion_matrix(
#     192     y_true,
#     193     y_pred,
#     194     sample_weight=sample_weight,
#     195     labels=unique_labels,
#     196     normalize="true",
#     197 ).ravel()
#     198 return fpr
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/sklearn/metrics/_classification.py:349, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     343 n_labels = labels.size
#     344 # If labels are not consecutive integers starting from zero, then
#     345 # y_true and y_pred must be converted into index form
#     346 need_index_conversion = not (
#     347     labels.dtype.kind in {"i", "u", "b"}
#     348     and np.all(labels == np.arange(n_labels))
# --> 349     and y_true.min() >= 0
#     350     and y_pred.min() >= 0
#     351 )
#     352 if need_index_conversion:
#     353     label_to_ind = {y: x for x, y in enumerate(labels)}
#
# File ~/miniconda3/envs/ma/lib/python3.10/site-packages/numpy/core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
df = results_baseline['variables']['Person']

viz(df, df.index.get_level_values('t'), df['wealth'].astype(float), df['race'])

# %%
# create baseline value
df_b1 = df_baseline.iloc[(df_baseline['race'] == 1).values] 
baseline1 = df_b1.groupby(level='t').mean()
# df_b
df_b0 = df_baseline.iloc[(df_baseline['race'] == 0).values] 
baseline0 = df_b0.groupby(level='t').mean()

# %%
df_x1 = df.iloc[(df['race'] == 1).values] 
df_wb1 = df_x1['wealth'] - baseline1['wealth']
df_x1['wealth'] = df_wb1




df_x0 = df.iloc[(df['race'] == 0).values] 
df_wb0 = df_x0['wealth'] - baseline0['wealth']
df_x0['wealth'] = df_wb0

df_xb = pd.concat([df_x0, df_x1])
# Out:
# /var/folders/_3/m4zxq5yx589d0965c6l5j1q80000gp/T/ipykernel_15756/2096043862.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1['wealth'] = df_wb1
# /var/folders/_3/m4zxq5yx589d0965c6l5j1q80000gp/T/ipykernel_15756/2096043862.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x0['wealth'] = df_wb0

# %%
viz(df_xb, df_xb.index.get_level_values('t'), df_xb['wealth'].astype(float), df_xb['race'])

# %% [markdown]
# ## Delta Function

# %%
# run baseline and normal model and save results

exp = ap.Experiment(VirusModel_baseline, parameters, iterations =5, record=True)
results_baseline = exp.run() 

df_baseline = results_baseline['variables']['Person']

exp = ap.Experiment(VirusModel, parameters_b, iterations =5, record=True)
results = exp.run() 

df = results['variables']['Person']

df = transform_pd(df)
df_baseline = transform_pd(df_baseline)
# Out:
# Scheduled runs: 5
# using predtrined clf
# Completed: 1, estimated time remaining: 0:26:10using predtrined clf
# Completed: 2, estimated time remaining: 0:21:21using predtrined clf
# Completed: 3, estimated time remaining: 0:14:46using predtrined clf
# Completed: 4, estimated time remaining: 0:07:30using predtrined clf
# Completed: 5, estimated time remaining: 0:00:00
# Experiment finished
# Run time: 0:37:56.618445
# Scheduled runs: 5
# Completed: 5, estimated time remaining: 0:00:00
# Experiment finished
# Run time: 0:37:35.575534
# /Users/uni/Documents/Git/abm/basic/utils.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baseline['intersect'] = list(df_baseline['gender'])
# /Users/uni/Documents/Git/abm/basic/utils.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baseline['intersect'] = list(df_baseline['gender'])

# %%
df_xb = delta_function('intersect', 'wealth', df, df_baseline)
print(df_xb)
viz(df_xb, df_xb.index.get_level_values('t'), df_xb['wealth'].astype(float), df_xb['intersect'])
# Out:
#                         wealth   health  fraud_pred  fraud  race  gender  \
# iteration obj_id t
# 0         7      1    0.379099  0.37454           0      0     1       0
#                  2    0.420945  0.37454           0      1     1       0
#                  3    0.396633  0.37454           1      0     1       0
#                  4    0.369067  0.37454           1      1     1       0
#                  5    0.337495  0.37454           1      0     1       0
# ...                        ...      ...         ...    ...   ...     ...
# 4         197    96  -0.755208  0.37454           1      0     0       1
#                  97  -0.755208  0.37454           1      1     0       1
#                  98  -0.755208  0.37454           1      1     0       1
#                  99  -0.755208  0.37454           1      1     0       1
#                  100 -0.755208  0.37454           1      1     0       1
#
#                       convicted  eod_gender  eod_race  dpd_gender  dpd_race  \
# iteration obj_id t
# 0         7      1            0    0.527307  0.842105    0.527307  0.842105
#                  2            0    0.641975  0.585366    0.641975  0.585366
#                  3            1    0.725275  0.564873    0.725275  0.564873
#                  4            1    0.909091  0.708955    0.909091  0.708955
#                  5            1    0.714286  0.719064    0.714286  0.719064
# ...                         ...         ...       ...         ...       ...
# 4         197    96           1    0.628478  0.800000    0.628478  0.800000
#                  97           1    0.533688  0.852174    0.533688  0.852174
#                  98           1    0.788333  0.869136    0.788333  0.869136
#                  99           1    0.800000  0.450000    0.800000  0.450000
#                  100          1    0.567633  0.188034    0.567633  0.188034
#
#                       misclassifications intersect
# iteration obj_id t
# 0         7      1                     0       fnw
#                  2                     1       fnw
#                  3                     1       fnw
#                  4                     0       fnw
#                  5                     1       fnw
# ...                                  ...       ...
# 4         197    96                    1        mw
#                  97                    0        mw
#                  98                    0        mw
#                  99                    0        mw
#                  100                   0        mw
#
# [100000 rows x 13 columns]
# /Users/uni/Documents/Git/abm/basic/utils.py:72: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wb1 = df.iloc[(df[disc_axis] == i).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
# /Users/uni/Documents/Git/abm/basic/utils.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1[y_axis] = df_wb1
# /Users/uni/Documents/Git/abm/basic/utils.py:72: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wb1 = df.iloc[(df[disc_axis] == i).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
# /Users/uni/Documents/Git/abm/basic/utils.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1[y_axis] = df_wb1
# /Users/uni/Documents/Git/abm/basic/utils.py:72: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wb1 = df.iloc[(df[disc_axis] == i).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
# /Users/uni/Documents/Git/abm/basic/utils.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1[y_axis] = df_wb1
# /Users/uni/Documents/Git/abm/basic/utils.py:72: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_wb1 = df.iloc[(df[disc_axis] == i).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
# /Users/uni/Documents/Git/abm/basic/utils.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x1[y_axis] = df_wb1

# %% [markdown]
# Do I want this or do I want just one line that indicates if r0 or r1 profits more? This

# %%
# def delta_function(disc_axis, y_axis, df, df_baseline):
#     """ Delta function visualizes absolute difference between baseline scenario and more complex scenario """

#     df_b1 = df_baseline.iloc[(df_baseline[disc_axis] == 1).values] 
#     df_wb1 = df.iloc[(df[disc_axis] == 1).values][y_axis] - df_b1.groupby(level='t').mean()[y_axis]
#     df_x1 = df.iloc[(df[disc_axis] == 1).values]
#     df_x1[y_axis] = df_wb1
    
#     df_b0 = df_baseline.iloc[(df_baseline[disc_axis] == 0).values] 
#     df_wb0 = df.iloc[(df[disc_axis] == 0).values] [y_axis] - df_b0.groupby(level='t').mean()[y_axis]
#     df_x0 = df.iloc[(df[disc_axis] == 0).values]
#     df_x0[y_axis] = df_wb0
    
#     return pd.concat([df_x0, df_x1])

# %%
# create baseline value fraud prediction medium income

df_b1 = df_baseline.iloc[(df_baseline['fraud_pred'] == 1).values] 
baseline1 = df_b1.groupby(level='t').mean()
# df_b
df_b0 = df_baseline.iloc[(df_baseline['fraud_pred'] == 0).values] 
baseline0 = df_b0.groupby(level='t').mean()

baseline0
df_b0

# df_x1 = df.iloc[(df_baseline['fraud_pred'] == 1).values] 
# df_wb1 = df_x1['wealth'] - baseline1['wealth']
# df_x1['wealth'] = df_wb1




df_x0 = df_baseline.iloc[(df_baseline['fraud_pred'] == 0).values] 
df_wb0 = df_x0['wealth'] - baseline0['wealth']
df_x0['wealth'] = df_wb0

df_xb = pd.concat([df_x0, df_x1])

df_xb
# Out:
# /var/folders/_3/m4zxq5yx589d0965c6l5j1q80000gp/T/ipykernel_73611/296530877.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_x0['wealth'] = df_wb0
#                         wealth  fraud_pred  fraud  race  gender  convicted
# iteration obj_id t
# 0         1      1   -0.097182           0      0     0       1          0
#                  2   -0.098531           0      0     0       1          0
#                  3   -0.098119           0      0     0       1          0
#                  4   -0.097747           0      1     0       1          0
#                  5   -0.098071           0      0     0       1          0
# ...                        ...         ...    ...   ...     ...        ...
# 4         498    96  -0.460377           1      0     1       1          1
#                  97  -0.459618           1      1     1       1          1
#                  98  -0.460181           1      1     1       1          1
#                  99  -0.459802           1      1     1       1          1
#                  100 -0.460165           1      1     1       1          1
#
# [608572 rows x 6 columns]
